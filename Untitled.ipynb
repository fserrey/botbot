# %%
import telebot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cd49586ddaa7> in <module>
# ----> 1 import telebot
#
# ModuleNotFoundError: No module named 'telebot'

# %%
# !pip install pyTelegramBotAPI
# Out:
# ...
#   Using cached pyTelegramBotAPI-3.7.1.tar.gz (70 kB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /home/fserrey/miniconda3/envs/botbot/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5xaw96qj/pyTelegramBotAPI/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5xaw96qj/pyTelegramBotAPI/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-mfye0fdx
#        cwd: /tmp/pip-install-5xaw96qj/pyTelegramBotAPI/
#   Complete output (49 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/telebot
#   copying telebot/types.py -> build/lib/telebot
#   copying telebot/apihelper.py -> build/lib/telebot
#   copying telebot/handler_backends.py -> build/lib/telebot
# ...

# %%
import requests
from bs4 import BeautifulSoup

termino = 'hla'

# %%
page = requests.get('https://dle.rae.es/' + termino)
soup = BeautifulSoup(page.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head><link as="script" href="/js/191127.js" rel="preload"/>
# <link as="style" href="/css/191211.css" rel="preload"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://dle.rae.es/" rel="canonical">
# <title>Diccionario de la lengua española | Edición del Tricentenario | RAE - ASALE</title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Versión electrónica 23.3 del «Diccionario de la lengua española», obra lexicográfica académica por excelencia." name="description">
# ...

# %%
type(soup) 7lsKMtR
# Out:
#   File "<ipython-input-28-7a58bc1e1c1e>", line 1
#     type(soup) 7lsKMtR
#                ^
# SyntaxError: invalid syntax

# %%
print(soup.title.text)
# Out:
# Diccionario de la lengua española | Edición del Tricentenario | RAE - ASALE

# %%
print(soup.article.text)

# %%
soup.find_all('div', {'class': 'BNeawe iBp4i AP7Wnd'})
# Out:
# [<div class="container">
#  <div class="header__region region region-header">
#  <div class="dle-header">
#  <div class="col-3 align-left"><a href="https://www.rae.es" rel="noopener" target="_blank" title="Real Academia Española"><img alt="Real Academia Española" class="b-lazy" data-src="/images/logos/rae.png" src="..."/><noscript><img alt="Real Academia Española" src="/images/logos/rae.png"/></noscript></a></div>
#  <div class="col-3-centro align-center"><a href="/" title="«Diccionario de la lengua española»"><div class="spr_dle90x110"></div></a></div>
#  <div class="col-3 align-right"><a href="https://www.asale.org" rel="noopener" target="_blank" title="Asociación de Academias de la Lengua Española"><img alt="Asociación de Academias de la Lengua Española" class="b-lazy" data-src="/images/logos/ASALE2.png" src="..."/><noscript><img alt="Asociación de Academias de la Lengua Española" src="/images/logos/ASALE2.png"/></noscript></a></div>
#  </div>
#  <div class="cb"></div>
# ...

# %%
parsed_word = soup.find_all('div', {'class': 'BNeawe iBp4i AP7Wnd'})[1].find_all(text=True, recursive=True)
time = f'⏰ In {place} is {parsed_time[0]}'
return time

# %%
#Importing packages
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome('/usr/bin/google-chrome')
driver.get('https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p702')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-10-2992d0887f48> in <module>
# ----> 1 driver = webdriver.Chrome('/usr/bin/google-chrome')
#       2 driver.get('https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p702')
#
# ~/anaconda3/envs/botbot/lib/python3.8/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~/anaconda3/envs/botbot/lib/python3.8/site-packages/selenium/webdriver/common/service.py in start(self)
#      96         count = 0
#      97         while True:
# ...
